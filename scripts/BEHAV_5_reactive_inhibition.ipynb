# %%
# load librairies
import numpy as np
import pandas as pd
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
import matplotlib.pyplot as plt
import os
from os.path import join
import seaborn as sns
import statsmodels.api as sm
import scipy
import json
import statsmodels.formula.api as smf
from collections import defaultdict
from scipy.stats import wilcoxon, ttest_rel

from functions import utils, plotting, io, behav_analysis

# %%
# pick format to save figures : png for quick visualization, pdf for illustrator
save_as = 'png'
color_dict = {
    'DBS ON': '#20a39e', 
    'DBS OFF': '#ef5b5b', 
    'control': '#ffba49', 
    'preop': '#8E7DBE',
    'Session 1': "#206ea1", 
    'Session 2': "#5FA363", 
    }
visualize_by = 'subject' # pick whether to visualize by condition (DBS ON, DBS OFF, control) or by subject id

# %% [markdown]
# # 1. Select subjects, create color palette and load data #

# %%
# Use the Included or excluded.xlsx document:
working_path = os.path.dirname(os.getcwd())

data_path = json.load(open(join(working_path, 'scripts', 'SETTINGS.json')))["DATA_STORAGE_PATH"]
behav_data_path = join(data_path, "behav")


results_path = json.load(open(join(working_path, 'scripts', 'SETTINGS.json')))["RESULTS_SAVING_PATH"]
if not os.path.exists(results_path):
    os.makedirs(results_path)  # Create the directory if it doesn't exist
# results_path = join(working_path, "results")

behav_results_saving_path = join(results_path, "behav_results")
if not os.path.isdir(behav_results_saving_path):
    os.makedirs(behav_results_saving_path)

# read the json file containing the included and excluded subjects
# Open and read the JSON file
included_excluded_file = join(results_path, 'final_included_subjects.json')
with open(included_excluded_file, 'r') as file:
    included_subjects = json.load(file)

# %%
included_subjects
# Out:
# ['C003 mSST',
#  'C004 mSST',
#  'C006 mSST',
#  'C007 mSST',
#  'C008 mSST',
#  'C009 mSST',
#  'C010 mSST',
#  'C011 mSST',
#  'C012 mSST',
#  'C013 mSST',
#  'C014 mSST',
#  'C015 mSST',
#  'sub006 DBS ON mSST',
#  'sub006 DBS OFF mSST',
#  'sub011 DBS OFF mSST',
#  'sub011 DBS ON mSST',
#  'sub012 DBS ON mSST',
#  'sub012 DBS OFF mSST',
#  'sub015 DBS OFF mSST',
#  'sub015 DBS ON mSST',
#  'sub019 DBS ON mSST',
#  'sub019 DBS OFF mSST',
#  'sub023 DBS OFF mSST',
#  'sub023 DBS ON mSST',
#  'sub025 DBS ON mSST',
#  'sub025 DBS OFF mSST',
#  'sub027 DBS ON mSST',
#  'sub027 DBS OFF mSST',
#  'sub028 DBS OFF mSST',
#  'sub028 DBS ON mSST',
#  'sub029 DBS ON mSST',
#  'sub029 DBS OFF mSST',
#  'sub032 DBS ON mSST',
#  'sub032 DBS OFF mSST',
#  'sub033 DBS ON mSST',
#  'sub033 DBS OFF mSST']

# %%
subject_colors = utils.create_color_palette(included_subjects)
utils.plot_color_palette(
    subject_colors = subject_colors,
    save_as='png', 
    saving_path=behav_results_saving_path
    )
# Out:
# ['C003', 'C004', 'C006', 'C007', 'C008', 'C009', 'C010', 'C011', 'C012', 'C013', 'C014', 'C015', 'sub006', 'sub011', 'sub012', 'sub015', 'sub019', 'sub023', 'sub025', 'sub027', 'sub028', 'sub029', 'sub032', 'sub033']

# %%
# load excel files for all included subjects and extract stats
data = io.load_behav_data(included_subjects, behav_data_path)
stats = utils.extract_stats(data)
# Out:
# C003 mSST
# C004 mSST
# C006 mSST
# C007 mSST
# C008 mSST
# C009 mSST
# C010 mSST
# C011 mSST
# C012 mSST
# C013 mSST
# C014 mSST
# C015 mSST
# sub006 DBS ON mSST
# sub006 DBS OFF mSST
# sub011 DBS OFF mSST
# sub011 DBS ON mSST
# sub012 DBS ON mSST
# sub012 DBS OFF mSST
# sub015 DBS OFF mSST
# sub015 DBS ON mSST
# sub019 DBS ON mSST
# sub019 DBS OFF mSST
# sub023 DBS OFF mSST
# sub023 DBS ON mSST
# sub025 DBS ON mSST
# sub025 DBS OFF mSST
# sub027 DBS ON mSST
# sub027 DBS OFF mSST
# sub028 DBS OFF mSST
# sub028 DBS ON mSST
# sub029 DBS ON mSST
# sub029 DBS OFF mSST
# sub032 DBS ON mSST
# sub032 DBS OFF mSST
# sub033 DBS ON mSST
# sub033 DBS OFF mSST
# GO omissions for C003 mSST: 26 out of 240 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for C003 mSST: 0.3670886075949367
# GO omissions for C004 mSST: 4 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for C004 mSST: 0.55
# GO omissions for C006 mSST: 14 out of 240 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for C006 mSST: 0.4
# GO omissions for C007 mSST: 9 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for C007 mSST: 0.43333333333333335
# GO omissions for C008 mSST: 7 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for C008 mSST: 0.4666666666666667
# GO omissions for C009 mSST: 4 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for C009 mSST: 0.48333333333333334
# GO omissions for C010 mSST: 20 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for C010 mSST: 0.43333333333333335
# GO omissions for C011 mSST: 18 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for C011 mSST: 0.43333333333333335
# GO omissions for C012 mSST: 24 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for C012 mSST: 0.4666666666666667
# GO omissions for C013 mSST: 20 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for C013 mSST: 0.43333333333333335
# GO omissions for C014 mSST: 13 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for C014 mSST: 0.48333333333333334
# GO omissions for C015 mSST: 18 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for C015 mSST: 0.45
# GO omissions for sub006 DBS ON mSST: 50 out of 240 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub006 DBS ON mSST: 0.4
# GO omissions for sub006 DBS OFF mSST: 5 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub006 DBS OFF mSST: 0.48333333333333334
# GO omissions for sub011 DBS OFF mSST: 32 out of 240 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub011 DBS OFF mSST: 0.4
# GO omissions for sub011 DBS ON mSST: 21 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub011 DBS ON mSST: 0.43333333333333335
# GO omissions for sub012 DBS ON mSST: 13 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub012 DBS ON mSST: 0.43333333333333335
# GO omissions for sub012 DBS OFF mSST: 10 out of 179 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub012 DBS OFF mSST: 0.4666666666666667
# GO omissions for sub015 DBS OFF mSST: 25 out of 240 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub015 DBS OFF mSST: 0.425
# GO omissions for sub015 DBS ON mSST: 13 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub015 DBS ON mSST: 0.4166666666666667
# GO omissions for sub019 DBS ON mSST: 13 out of 240 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub019 DBS ON mSST: 0.4
# GO omissions for sub019 DBS OFF mSST: 3 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub019 DBS OFF mSST: 0.45
# GO omissions for sub023 DBS OFF mSST: 22 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub023 DBS OFF mSST: 0.48333333333333334
# GO omissions for sub023 DBS ON mSST: 10 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub023 DBS ON mSST: 0.45
# GO omissions for sub025 DBS ON mSST: 17 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub025 DBS ON mSST: 0.45
# GO omissions for sub025 DBS OFF mSST: 26 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub025 DBS OFF mSST: 0.55
# GO omissions for sub027 DBS ON mSST: 39 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub027 DBS ON mSST: 0.55
# GO omissions for sub027 DBS OFF mSST: 9 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub027 DBS OFF mSST: 0.4666666666666667
# GO omissions for sub028 DBS OFF mSST: 11 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub028 DBS OFF mSST: 0.45
# GO omissions for sub028 DBS ON mSST: 3 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub028 DBS ON mSST: 0.5
# GO omissions for sub029 DBS ON mSST: 14 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub029 DBS ON mSST: 0.4666666666666667
# GO omissions for sub029 DBS OFF mSST: 11 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub029 DBS OFF mSST: 0.48333333333333334
# GO omissions for sub032 DBS ON mSST: 30 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub032 DBS ON mSST: 0.4666666666666667
# GO omissions for sub032 DBS OFF mSST: 47 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub032 DBS OFF mSST: 0.4166666666666667
# GO omissions for sub033 DBS ON mSST: 28 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub033 DBS ON mSST: 0.45
# GO omissions for sub033 DBS OFF mSST: 46 out of 180 go trials. Replacing with maximum available RT = 1000ms.
# p(respond|signal) for sub033 DBS OFF mSST: 0.4166666666666667

# %%
# fetch excel file containing recording and subject information
onedrive_path = json.load(open(join(working_path, 'scripts', 'SETTINGS.json')))["ONEDRIVE_PATH"]
excel_file = join(onedrive_path, 'WP3_rec_info.xlsx')
# select the relevant sheet called 'Subjects List'
subject_info_df = pd.read_excel(excel_file, sheet_name='Subjects List')
control_info_df = pd.read_excel(excel_file, sheet_name='Controls List')

# get session order and save it to 'session_info.txt'
behav_analysis.get_session_order(
    included_subjects = included_subjects,
    subject_info_df = subject_info_df,
    behav_results_saving_path = behav_results_saving_path
)
# Out:
# 6 subjects started with first session in OFF condition
# 6 subjects started with first session in ON condition

# %% [markdown]
# # 2. Visualize reactive inhibition (SSRT) per subject/condition #

# %%
variable_of_interest = 'SSRT (ms)'
temp_save = join(behav_results_saving_path, "Response inhibition")
if not os.path.isdir(temp_save):
    os.makedirs(temp_save)    
for viz in ['subject', 'condition']:
    behav_analysis.plot_variable_of_interest(
        stats = stats,
        color_dict = color_dict,
        subject_colors = subject_colors,
        variable_of_interest = variable_of_interest,
        colored_by = viz,
        saving_path = temp_save,
        save_as = save_as,
        show_plot = True,
        run_stats = True,
        correct_multiple_comparisons = False
    )
